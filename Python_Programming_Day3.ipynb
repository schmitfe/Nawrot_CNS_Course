# %% [markdown]
# <a href="https://colab.research.google.com/github/schmitfe/Nawrot_CNS_Course/blob/main/Python_Programming_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises

# %% [markdown]
# 1- Two arrays below show the maximum and minimum temperature of Cologne in 2018 (0th index element is the value for January, 1th index for February, 2nd index for March and so on.). What is the average temperature for each month? Put the average temperature values in a new array called `mean_temp`. Now plot `mean_temp` versus `months` where `months=['January', 'February', 'March', ..., 'December']`.
# ```
# max_temp = [5,7,11,15,19,22,24,24,20,15,10,6]
# min_temp = [-1,-1,2,4,8,11,13,13,10,7,3,0]
# ```

# %%
#You need DataLad so that you can download the dataset.
# !pip install datalad #See also https://stackoverflow.com/a/55253499 for a cleaner implementation

#Download from Dropbox
# !datalad download-url  'https://www.dropbox.com/s/9bxjmlf4lhzbh27/PythonCourseData.zip?dl=1'
#unzip data
# !unzip 'PythonCourseData.zip'
#Show runtime content
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 79.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 7.1 MB/s eta 0:00:00
# ...
# It is highly recommended to configure Git before using DataLad. Set both 'user.name' and 'user.email' configuration variables.
# [INFO   ] Downloading 'https://www.dropbox.com/s/9bxjmlf4lhzbh27/PythonCourseData.zip?dl=1' into '/content/'
# download_url(ok): /content/PythonCourseData.zip (file)
# Archive:  PythonCourseData.zip
#   inflating: CarData.mat
#   inflating: CologneWeather.csv
#   inflating: SpVC_041222_cortex1_1cell003.mat

# %%
# write your solution here

# %% [markdown]
# --------------------------------

# %% [markdown]
# 2- Load the data file ‘CarData.mat’. Note that it is a matlab file (.mat). So you will need to use the function `loadmat` from `scipy.io`.
#
# Read the string in the key ‘Description’. How many dimensions does the values of the key 'M' have? Note, not for all cars all measures were available. The missing elements in the matrix are represented by the value NaN (Not a number). NaN basically refers to numerically useless element.
#
# 2.1. Why do you think it is usefull to define such a thing as NaN in a programming language dedicated to quantitative science?  Discuss with your partner.
#
#
# 2.2. How many different numbers of cylinders do these cars have? Explore and use the numpy function `unique`.
#
#
# 2.3. Find the indices of all cars that have 4 or less cylinders and assign this to the variable ‘idx_4’. How much do these cars weigh on average? How much petrol do these cars take on average? Careful, if you average over NaNs your result will also be a NaN (Why?). Use the numpy function `isnan` (or the negation of it) to find those entries. Use the numpy function `nanmean` to compute the mean by ignoring NaN entries. Why is this dangerous to use and why should you always test for NaNs in your data?
#
#
# 2.4. Find the indices of all cars that have 6 or more cylinders and assign this to the variable idx_6. Again find out the average weight of those cars. Should these index arrays contain any identical index number? To check this you can explore and use the numpy function `intersect1d`. Which average weight is larger?
#
#
# 2.5. Test for a significant difference in the weight of cars with less or equal 4 cylinders and cars with 6 or more cylinders using the Wilcoxon rank sum test using the scipy function `ranksum` (scipy.stats.ranksum).
#
#
# 2.6. Now consider again all cars. Do you expect that the weight of the car correlates with the amount of petrol it uses? Compute the linear correlation coefficient using the function corrcoeff and report the significance of this correlation using a t-test (see documentation of `scipy.stats.pearsonnr`) or the spearman rank order correlation (as option with function corr, does not assume normal distribution).

# %%
# write your solution here

# %% [markdown]
# -------
